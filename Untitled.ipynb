# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 105, dtype=float)
z = 0.0365*x**2+0.8629*x-14.986

# %%
plt.plot(z,x)
plt.title('Diverging nozzle parabola')
plt.xlabel('z[in]')
plt.ylabel('r[in]')
# Out:
# Text(0, 0.5, 'r[in]')
